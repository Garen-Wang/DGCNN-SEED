# %%
import scipy.io as scio
import numpy as np #导入矩阵处理库

# %%
data = scio.loadmat('../SEED/DE/DE_1.mat')
DE=np.array(data) #将matlab数据赋值给python变量

# %%
DE
# Out:
# array({'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Sat Jun 03 21:16:42 2017', '__version__': '1.0', '__globals__': [], 'DE_feature': array([[[28.2134122 , 23.35981044, 20.51525207, 18.16684024,
#          17.0527004 ],
#         [28.21729617, 23.35570993, 20.5130418 , 18.1666351 ,
#          17.05314969],
#         [28.22004992, 23.34956694, 20.50992358, 18.16584321,
#          17.05314894],
#         ...,
#         [26.82003488, 23.08412121, 20.28601109, 17.97821797,
#          16.616673  ],
#         [26.8162563 , 23.08414692, 20.28641409, 17.97770318,
#          16.61525482],
#         [26.81760202, 23.08666703, 20.28756589, 17.97790211,
#          16.61523714]],
#
#        [[27.66592246, 23.37122229, 20.415539  , 18.06727558,
#          16.98630626],
#         [27.66615803, 23.36809755, 20.41324084, 18.06654991,
#          16.98661194],
#         [27.66719941, 23.36323577, 20.41043131, 18.06548189,
#          16.98615044],
#         ...,
# ...
